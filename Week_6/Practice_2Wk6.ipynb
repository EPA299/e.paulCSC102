# %%
# Import necessary libraries
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk

# Function to display a welcome message in a new window
def welcomeMessage(username):
    # Create a new window
    window = tk.Toplevel(root)
    window.title("Admin Box")
    window.geometry("500x200")

    # Display welcome message
    label_1 = tk.Label(window, text=f"Welcome {username}\n")
    label_1.pack()
    label_2 = tk.Label(window, text="This is Python GUI with Tkinter")
    label_2.pack()

    # Run the Tkinter event loop
    root.mainloop()

# Function to handle login submission
def submit():
    # Get the entered username and password
    username = username_entry.get()
    password = password_entry.get()

    # Check if credentials are valid
    if username == "Mary" and password == "cos102":
        welcomeMessage(username)  # Show welcome message on success
    else:
        messagebox.showerror("Login", "Invalid username or password")  # Show error message

    # Create the main login form window
import tkinter as tk

# Define the login form window
root = tk.Tk()
root.title("Login Form")  # Set the title of the window
root.geometry("500x200")  # Set the window size

# Create the username label and entry field
username_label = tk.Label(root, text="Username:")
username_label.pack()
username_entry = tk.Entry(root)
username_entry.pack()

# Create the password label and entry field (masked input)
password_label = tk.Label(root, text="Password:")
password_label.pack()
password_entry = tk.Entry(root, show="*")  # Mask password input
password_entry.pack()

# Define the submit function
def submit():
    username = username_entry.get()
    password = password_entry.get()
    print("Username:", username)
    print("Password:", password)

# Create the submit button
submit_button = tk.Button(root, text="Submit", command=submit)
submit_button.pack()

# Run the main event loop
root.mainloop()
